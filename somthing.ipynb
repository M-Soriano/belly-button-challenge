# %%
import json
import pandas as pd
import pprint

# %%
# Load the JSON file
with open('samples.json') as f:
    data = json.load(f)

# Check the number of data points
num_data_points = len(data)
print(f'The number of data points in the JSON file is: {num_data_points}')
# Out:
# The number of data points in the JSON file is: 3

# %%
idot=pd.DataFrame(data['samples'][0])
idot
# Out:
#      id  otu_ids  sample_values  \
# 0   940     1167            163
# 1   940     2859            126
# 2   940      482            113
# 3   940     2264             78
# 4   940       41             71
# ..  ...      ...            ...
# 75  940      340              2
# 76  940     2110              2
# 77  940     2188              2
# 78  940      357              2
# 79  940      342              2
#
#                                            otu_labels
# 0   Bacteria;Bacteroidetes;Bacteroidia;Bacteroidal...
# 1   Bacteria;Firmicutes;Clostridia;Clostridiales;I...
# 2                                            Bacteria
# 3   Bacteria;Firmicutes;Clostridia;Clostridiales;I...
# 4                                            Bacteria
# ..                                                ...
# 75                                           Bacteria
# 76       Bacteria;Firmicutes;Clostridia;Clostridiales
# 77  Bacteria;Firmicutes;Clostridia;Clostridiales;I...
# ...

# %%
idot.map()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 idot.map()
#
# NameError: name 'idot' is not defined

# %%
sothingss= pd.DataFrame(data['samples'])

# %%
data.keys()
# Out:
# dict_keys(['names', 'metadata', 'samples'])

# %%
sothingss
# Out:
#        id                                            otu_ids  \
# 0     940  [1167, 2859, 482, 2264, 41, 1189, 352, 189, 23...
# 1     941  [2722, 944, 2419, 2539, 3450, 1795, 2389, 1314...
# 2     943                                             [1795]
# 3     944  [922, 3555, 943, 1013, 1795, 944, 3368, 923, 1...
# 4     945  [944, 1795, 922, 2419, 2859, 943, 2722, 1167, ...
# ..    ...                                                ...
# 148  1574  [482, 909, 2419, 944, 1795, 1167, 2859, 922, 2...
# 149  1576  [1929, 1770, 1926, 151, 1016, 3064, 477, 3184,...
# 150  1577  [922, 1795, 151, 3184, 1770, 1929, 3134, 1399,...
# 151  1581  [1795, 3312, 1399, 3134, 3288, 3120, 151, 954,...
# 152  1601  [1929, 3030, 1795, 894, 1167, 1926, 3042, 1930...
#
#                                          sample_values  \
# 0    [163, 126, 113, 78, 71, 51, 50, 47, 40, 40, 37...
# 1    [194, 178, 162, 92, 84, 40, 37, 28, 27, 24, 21...
# 2                                                  [2]
# ...
